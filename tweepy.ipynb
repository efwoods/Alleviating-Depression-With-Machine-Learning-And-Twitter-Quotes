# %% [markdown]
# [How to get tweets by Python and Twitter API 2022](https://medium.com/mlearning-ai/how-to-get-tweets-by-python-and-twitter-api-2022-a440c635c3ac)

# %%
#!pip install tweepy
#!pip install configparser
#!pip install pandas
# Out:
#   Cell In [1], line 1
#     pip install tweepy
#         ^
# SyntaxError: invalid syntax

# %%
import configparser
import tweepy

# read config
config = configparser.ConfigParser()
config.read('./code/config/config.ini')

api_key = config['twitter']['api_key']
api_key_secret = config['twitter']['api_key_secret']

access_token = config['twitter']['access_token']
access_token_secret = config['twitter']['access_token_secret']

# authenticate
auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
public_tweets = api.home_timeline()
print(public_tweets)
# Out:
# [Status(_api=<tweepy.api.API object at 0x10553cac0>, _json={'created_at': 'Sat Dec 10 14:08:11 +0000 2022', 'id': 1601579533588922368, 'id_str': '1601579533588922368', 'text': 'It makes no sense that our good accounts are being banned without the blatantly pornographic accounts being banned.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1593998704381689857, 'id_str': '1593998704381689857', 'name': '@KatoShinya@mastodon.world', 'screen_name': 'kato__shinya', 'location': 'Somewhere, Japan', 'description': '👋 Coding 10+ years┆OSS Developer┆Hacker\n👨\u200d💻 Author of twitter_api_v2, mastodon_api, many Dart/Flutter packages \n🏠 https://t.co/UpZMIJThjK\n🇯🇵 He/Him/His', 'url': 'https://t.co/5ywwi0xsnP', 'entities': {'url': {'urls': [{'url': 'https://t.co/5ywwi0xsnP', 'expanded_url': 'https://github.com/myConsciousness', 'display_url': 'github.com/myConsciousness', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/UpZMIJThjK', 'expanded_url': 'http://shinyakato.dev', 'display_url': 'shinyakato.dev', 'indices': [114, 137]}]}}, 'protected': False, 'followers_count': 119, 'friends_count': 405, 'listed_count': 0, 'created_at': 'Sat Nov 19 16:04:47 +0000 2022', 'favourites_count': 1488, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 165, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1601577506011750401/_9JX-Ij-_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1601577506011750401/_9JX-Ij-_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1593998704381689857/1670649748', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 12, 10, 14, 8, 11, tzinfo=datetime.timezone.utc), id=1601579533588922368, id_str='1601579533588922368', text='It makes no sense that our good accounts are being banned without the blatantly pornographic accounts being banned.', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x10553cac0>, _json={'id': 1593998704381689857, 'id_str': '1593998704381689857', 'name': '@KatoShinya@mastodon.world', 'screen_name': 'kato__shinya', 'location': 'Somewhere, Japan', 'description': '👋 Coding 10+ years┆OSS Developer┆Hacker\n👨\u200d💻 Author of twitter_api_v2, mastodon_api, many Dart/Flutter packages \n🏠 https://t.co/UpZMIJThjK\n🇯🇵 He/Him/His', 'url': 'https://t.co/5ywwi0xsnP', 'entities': {'url': {'urls': [{'url': 'https://t.co/5ywwi0xsnP', 'expanded_url': 'https://github.com/myConsciousness', 'display_url': 'github.com/myConsciousness', 'indices': [0, 23]}]}, 'description': {'urls': [{' ...

# %%
evanWoods = api.search_users("EvanWoods")

# %%
print(evanWoods)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 evanWoods["id"]
#
# TypeError: list indices must be integers or slices, not str

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 df.head()
#
# AttributeError: 'ResultSet' object has no attribute 'head'

# %%
import pandas as pd

# create dataframe
columns = ['Time', 'User', 'Tweet']

data = []
for tweet in public_tweets:
    data.append([tweet.created_at, tweet.user.screen_name, tweet.text])

df = pd.DataFrame(data, columns=columns)

df.to_csv('tweets.csv')
